# %% [markdown]
# # Problem Set 1
# ## Annie Bryan

# %% [markdown]
# ### Imports

# %%
using Pkg
using CSV
using DataFrames
using Interact
using Plots
using Dates
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-7056661556529831618\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-7391492827349670885\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio-jupyter-notebook\"]) {\n            // Extension already loaded.\n    
# ...

# %% [markdown]
# ### Exercise 1: Visualizing the data over time

# %%
url = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv"
download(url, "covid_data.csv")
data = CSV.read("covid_data.csv")
rename!(data, 1 => "Province", 2 => "Country")
all_countries = collect(data[:,2])
# Out:
# 262-element Array{String,1}:
#  "Afghanistan"
#  "Albania"
#  "Algeria"
#  "Andorra"
#  "Angola"
#  "Antigua and Barbuda"
#  "Argentina"
#  "Armenia"
#  "Australia"
#  "Australia"
#  "Australia"
#  "Australia"
#  "Australia"
#  ⋮
#  "United Kingdom"
#  "United Kingdom"
#  "MS Zaandam"
#  "Botswana"
#  "Burundi"
#  "Sierra Leone"
#  "Netherlands"
#  "Malawi"
#  "United Kingdom"
#  "France"
#  "South Sudan"
#  "Western Sahara"

# %%
countries = ["China", "Japan", "Korea, South", "US", "United Kingdom", "France", "Germany", "Italy", "Spain", "Australia", "Canada"] 
# I added more than the pset specified out of interest
# Out:
# 11-element Array{String,1}:
#  "China"
#  "Japan"
#  "Korea, South"
#  "US"
#  "United Kingdom"
#  "France"
#  "Germany"
#  "Italy"
#  "Spain"
#  "Australia"
#  "Canada"

# %%
num_days = length(names(data)[5:end])
# Out:
# 75

# %%
accumulated_data = Dict()
for country in countries
    accumulated_data[country] = zeros(num_days)
end

for country in countries
    for index in 1:length(all_countries)
        if all_countries[index] == country
            for day in 1:num_days
                accumulated_data[country][day] += data[index,day+4]
            end
        end
    end
end

date_strings = String.(names(data))[5:end];
format = Dates.DateFormat("m/d/Y");
dates = parse.(Date, String.(names(data))[5:end], format) .+ Year(2000)

dates
# Out:
# 75-element Array{Date,1}:
#  2020-01-22
#  2020-01-23
#  2020-01-24
#  2020-01-25
#  2020-01-26
#  2020-01-27
#  2020-01-28
#  2020-01-29
#  2020-01-30
#  2020-01-31
#  2020-02-01
#  2020-02-02
#  2020-02-03
#  ⋮
#  2020-03-25
#  2020-03-26
#  2020-03-27
#  2020-03-28
#  2020-03-29
#  2020-03-30
#  2020-03-31
#  2020-04-01
#  2020-04-02
#  2020-04-03
#  2020-04-04
#  2020-04-05

# %%
p = plot()

for country in countries
    plot!(dates, accumulated_data[country], 
        xticks = dates[1:5:end], xrotation=45, leg=:topleft, 
        label=country, m=:o)
end

xlabel!("Date")
ylabel!("Number of confirmed cases")
title!("Confirmed COVID-19 cases")

p

# %%
p = plot()

for country in countries
    replace!(accumulated_data[country], 0=>NaN)
    plot!(dates, accumulated_data[country],
        xticks = dates[1:5:end], xrotation=45, leg=:topleft,
        label=country, m=:o,
        yscale=:log10)
end

xlabel!("Date")
ylabel!("Number of confirmed cases")
title!("Confirmed COVID-19 cases")

true_exponential = [1.2^i for i in 1:length(dates)]
plot!(dates, true_exponential, label="Exponential growth", linecolor="black", linewidth=3)
p

# %%
@manipulate for i in 1:num_days
    p = plot()
    plot!(xlim=dates)
    for country in countries
        replace!(accumulated_data[country], 0=>NaN)
        plot!(dates[1:i], accumulated_data[country][1:i],
            xticks = dates[1:5:end], xrotation=45, leg=:topleft,
            label=country, yscale=:log10)
    end

    xlabel!("Date")
    ylabel!("Number of confirmed cases")
    title!("Confirmed COVID-19 cases")
    
    true_exponential = [1.2^i for i in 1:num_days]
    plot!(dates, true_exponential, label="Exponential growth", linecolor="black", linewidth=3)
    
    p
end
# Out:
# Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Scope(Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :label), Any["i"], Dict{Symbol,Any}(:className => "interact ",:style => Dict{Any,Any}(:padding => "5px 10px 0px 10px")))], Dict{Symbol,Any}(:className => "interact-flex-row-left")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :input), Any[], Dict{Symbol,Any}(:max => 75,:min => 1,:attributes => Dict{Any,Any}(:type => "range",Symbol("data-bind") => "numericValue: index, valueUpdate: 'input', event: {change: function (){this.changes(this.changes()+1)}}","orient" => "horizontal"),:step => 1,:className => "slider slider is-fullwidth",:style => Dict{Any,Any}()))], Dict{Symbol,Any}(:className => "interact-flex-row-center")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes => Dic
# ...

# %% [markdown]
# ### Exercise 2: Visualizing Changes

# %%
total_cases_to_date = accumulated_data
# Out:
# Dict{Any,Any} with 11 entries:
#   "Japan"          => [2.0, 2.0, 2.0, 2.0, 4.0, 4.0, 7.0, 7.0, 11.0, 15.0  …  1…
#   "Germany"        => [NaN, NaN, NaN, NaN, NaN, 1.0, 4.0, 4.0, 4.0, 5.0  …  508…
#   "Canada"         => [NaN, NaN, NaN, NaN, 1.0, 1.0, 2.0, 2.0, 2.0, 4.0  …  468…
#   "France"         => [NaN, NaN, 2.0, 3.0, 3.0, 3.0, 4.0, 5.0, 5.0, 5.0  …  334…
#   "United Kingdom" => [NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, 2.0  …  147…
#   "Spain"          => [NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN  …  657…
#   "Korea, South"   => [1.0, 1.0, 2.0, 2.0, 3.0, 4.0, 4.0, 4.0, 4.0, 11.0  …  93…
#   "Italy"          => [NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, 2.0  …  864…
#   "China"          => [548.0, 643.0, 920.0, 1406.0, 2075.0, 2877.0, 5509.0, 608…
#   "Australia"      => [NaN, NaN, NaN, NaN, 4.0, 5.0, 5.0, 6.0, 9.0, 9.0  …  314…
#   "US"             => [1.0, 1.0, 2.0, 2.0, 5.0, 5.0, 5.0, 5.0, 5.0, 7.0  …  101…

# %%
new_cases = Dict()
for country in countries
    new_cases_by_country = [accumulated_data[country][i] - accumulated_data[country][i-6] for i in 7:num_days]
    new_cases[country] = new_cases_by_country
    replace!(new_cases[country], 0=>NaN)
end

new_cases
# Out:
# Dict{Any,Any} with 11 entries:
#   "Japan"          => [5.0, 5.0, 9.0, 13.0, 16.0, 16.0, 13.0, 15.0, 11.0, 7.0  …
#   "Germany"        => [NaN, NaN, NaN, NaN, NaN, 9.0, 8.0, 8.0, 8.0, 7.0  …  286…
#   "Canada"         => [NaN, NaN, NaN, NaN, 3.0, 3.0, 2.0, 2.0, 3.0, 1.0  …  340…
#   "France"         => [NaN, NaN, 3.0, 2.0, 3.0, 3.0, 2.0, 1.0, 1.0, 1.0  …  189…
#   "United Kingdom" => [NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN  …  967…
#   "Spain"          => [NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN  …  403…
#   "Korea, South"   => [3.0, 3.0, 2.0, 9.0, 9.0, 11.0, 11.0, 12.0, 15.0, 12.0  ……
#   "Italy"          => [NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN  …  329…
#   "China"          => [4961.0, 5444.0, 7221.0, 8396.0, 9816.0, 13753.0, 14207.0…
#   "Australia"      => [NaN, NaN, NaN, NaN, 8.0, 7.0, 7.0, 7.0, 4.0, 5.0  …  207…
#   "US"             => [4.0, 4.0, 3.0, 5.0, 3.0, 3.0, 6.0, 6.0, 6.0, 4.0  …  761…

# %%
@manipulate for i in 8:num_days
    p = plot()
    plot!(xlim=dates[8:num_days])
    for country in countries
        plot!(total_cases_to_date[country][7:i], new_cases[country][1:i-6],
            leg=:topleft,label=country,xscale=:log10,yscale=:log10, m=:o)
    end

    xlabel!("Total confirmed cases")
    ylabel!("New cases in the past week")
    title!("Confirmed COVID-19 cases")
    
    range = 1:10000:maximum(total_cases_to_date["US"])
    plot!(range, range, label="Exponential growth", linecolor="black")
    
    p
end
# Out:
# Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Scope(Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :label), Any["i"], Dict{Symbol,Any}(:className => "interact ",:style => Dict{Any,Any}(:padding => "5px 10px 0px 10px")))], Dict{Symbol,Any}(:className => "interact-flex-row-left")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :input), Any[], Dict{Symbol,Any}(:max => 75,:min => 8,:attributes => Dict{Any,Any}(:type => "range",Symbol("data-bind") => "numericValue: index, valueUpdate: 'input', event: {change: function (){this.changes(this.changes()+1)}}","orient" => "horizontal"),:step => 1,:className => "slider slider is-fullwidth",:style => Dict{Any,Any}()))], Dict{Symbol,Any}(:className => "interact-flex-row-center")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes => Dic
# ...

# %%
current_total_cases = []
current_new_cases = []

for country in countries
    append!(current_total_cases, total_cases_to_date[country][end])
    append!(current_new_cases, new_cases[country][end])
end

s = scatter()
scatter!(current_total_cases, current_new_cases, 
    leg=false,xscale=:log10,yscale=:log10, m=:o)

for country in countries
    annotate!(total_cases_to_date[country][end], new_cases[country][end]*1.2, text(country, 10, :black))
end

a = minimum([total_cases_to_date[i][end] for i in countries])
b = maximum([total_cases_to_date[i][end] for i in countries])
r = a:100:b
plot!(r, r, linecolor="black")

xlabel!("Total confirmed cases as of "*date_strings[end])
ylabel!("New cases in the week of "*date_strings[end-7]*"--"*date_strings[end])
title!("Recently confirmed COVID-19 cases") 

s
